# %%
import pandas as pd
import numpy as np

# Set a random seed for reproducibility
np.random.seed(42)

# Number of rows to generate
n = 1000

# Generate synthetic data
data = {
    'ProductType': np.random.choice(['Smart Watch', 'Fitness Tracker', 'Smart Treadmill'], size=n),
    'Age': np.random.randint(18, 71, size=n),
    'Gender': np.random.choice(['Male', 'Female'], size=n),
    'EducationLevel': np.random.randint(12, 21, size=n),
    'MaritalStatus': np.random.choice(['Single', 'Married', 'Divorced'], size=n),
    'WeeklyUsage': np.random.randint(1, 8, size=n),
    'FitnessLevel': np.random.randint(1, 6, size=n),
    'AnnualIncome': np.random.randint(30000, 120000, size=n),
    'StepsPerDay': np.random.randint(1000, 20001, size=n)
}

# Create the DataFrame
df = pd.DataFrame(data)

# Save to CSV
df.to_csv('SmartFitCustomerData.csv', index=False)

# Show the first few rows of the generated dataset
df.head()
# Out:
#        ProductType  Age  Gender  EducationLevel MaritalStatus  WeeklyUsage  \
# 0  Smart Treadmill   20    Male              16      Divorced            4
# 1      Smart Watch   68  Female              12        Single            4
# 2  Smart Treadmill   48  Female              20      Divorced            1
# 3  Smart Treadmill   57    Male              12        Single            1
# 4      Smart Watch   54  Female              19       Married            5
#
#    FitnessLevel  AnnualIncome  StepsPerDay
# 0             2         92699        19625
# 1             4         56957         7378
# 2             3         55464        10365
# 3             2         53649        12422
# 4             5         72065         5911

# %%
import matplotlib.pyplot as plt

# 1. Gender Ratio (Male vs Female) - Pie Chart
gender_counts = smart_fit_data['Gender'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90, explode=(0.05, 0.05))
plt.title("Gender Ratio (Male vs Female)")
plt.show()

# 2. Fitness Distribution - Bar Chart
fitness_counts = smart_fit_data['Fitness'].value_counts().sort_index()
plt.figure(figsize=(8, 6))
plt.bar(fitness_counts.index, fitness_counts.values)
plt.title("Fitness Distribution")
plt.xlabel("Fitness Score")
plt.ylabel("Number of Customers")
plt.xticks(fitness_counts.index)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# 3. Average Miles per Day by Product Type - Box Plot
plt.figure(figsize=(10, 6))
smart_fit_data.boxplot(column='Miles', by='Product', grid=False)
plt.title("Average Miles per Day by Product Type")
plt.suptitle('')  # Remove default title
plt.xlabel("Product Type")
plt.ylabel("Miles")
plt.show()

# 4. Usage Distribution (Days per Week) - Histogram
plt.figure(figsize=(8, 6))
plt.hist(smart_fit_data['Usage'], bins=range(1, smart_fit_data['Usage'].max() + 2), edgecolor='black', alpha=0.7)
plt.title("Usage Distribution (Days per Week)")
plt.xlabel("Days per Week")
plt.ylabel("Number of Customers")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_131656/3083205775.py in <module>
#       2
#       3 # 1. Gender Ratio (Male vs Female) - Pie Chart
# ----> 4 gender_counts = smart_fit_data['Gender'].value_counts()
#       5 plt.figure(figsize=(6, 6))
#       6 plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90, explode=(0.05, 0.05))
#
# NameError: name 'smart_fit_data' is not defined
